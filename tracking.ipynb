# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 18FD-E82F
#
#  Directory of D:\ANACONDA\envs\yolov4-deepsort-master
#
# 05/05/2021  03:04 PM    <DIR>          .
# 05/05/2021  03:04 PM    <DIR>          ..
# 05/05/2021  03:04 PM    <DIR>          .ipynb_checkpoints
# 05/05/2021  02:37 PM    <DIR>          checkpoints
# 09/28/2020  12:08 AM               225 conda-cpu.yml
# 09/28/2020  12:08 AM               269 conda-gpu.yml
# 09/28/2020  12:08 AM             3,012 convert_tflite.py
# 09/28/2020  12:08 AM             4,254 convert_trt.py
# 09/28/2020  12:08 AM    <DIR>          core
# 05/05/2021  02:36 PM    <DIR>          data
# 09/28/2020  12:08 AM    <DIR>          deep_sort
# 09/28/2020  12:08 AM             1,067 LICENSE
# 09/28/2020  12:08 AM    <DIR>          model_data
# 09/28/2020  12:08 AM            10,591 object_tracker.py
# 09/28/2020  12:08 AM    <DIR>          outputs
# 09/28/2020  12:08 AM             7,627 README.md
# ...

# %%
# !python save_model.py --weights ./data/yolov4-tiny-custom_best.weights --output ./checkpoints/yolov4-tiny-416 --model yolov4 --tiny
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 417, 417, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 208, 208, 32) 864         zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 208, 208, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python object_tracker.py --weights ./checkpoints/yolov4-tiny-416 --model yolov4 --video ./data/video/vid-6.mp4 --output ./outputs/tiny-2.avi --tiny
# Out:
# success
# Frame #:  1
#
# 1
# FPS: 1.46
# Frame #:  2
#
# 2
# FPS: 8.88
# Frame #:  3
#
# 2
# FPS: 9.62
# Frame #:  4
#
# 2
# FPS: 11.39
# Frame #:  5
#
# 2
# FPS: 11.33
# Frame #:  6
#
# 2
# FPS: 11.27
# Frame #:  7
#
# 2
# FPS: 9.10
# Frame #:  8
#
# 2
# FPS: 7.57
# Frame #:  9
#
# 2
# FPS: 10.02
# Frame #:  10
#
# 2
# FPS: 10.71
# Frame #:  11
#
# 2
# FPS: 11.27
# Frame #:  12
#
# 3
# FPS: 9.73
# Frame #:  13
#
# 2
# FPS: 11.66
# Frame #:  14
#
# 2
# FPS: 12.08
# Frame #:  15
#
# 1
# FPS: 13.37
# Frame #:  16
#
# 1
# FPS: 13.55
# Frame #:  17
#
# 3
# FPS: 10.90
# Frame #:  18
#
# 3
# FPS: 10.55
# Frame #:  19
#
# 2
# FPS: 7.65
# Frame #:  20
#
# 1
# FPS: 11.33
# Frame #:  21
#
# 1
# FPS: 10.33
# Frame #:  22
#
# 1
# FPS: 13.17
# Frame #:  23
#
# 0
# FPS: 15.70
# Frame #:  24
#
# 1
# FPS: 13.78
# Frame #:  25
#
# 2
# FPS: 11.39
# Frame #:  26
#
# 1
# FPS: 13.37
# Frame #:  27
#
# 2
# FPS: 12.05
# Frame #:  28
#
# 2
# FPS: 11.94
# Frame #:  29
#
# 3
# FPS: 10.67
# Frame #:  30
#
# ...
